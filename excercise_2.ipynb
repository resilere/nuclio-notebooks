# %% [markdown]
# # Data Visualisation Excercise 2 - Boston Housing Dataset

# %%
# !pip install --upgrade plotly
print(plotly.__version__)
# Out:
# 4.4.1

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

from sklearn.datasets import load_boston

boston_dataset = load_boston()
df = pd.DataFrame(boston_dataset['data'], columns=boston_dataset['feature_names'])
df['MEDV'] = boston_dataset['target'] # This is our target - Median value of owner-occupied homes in $1000s

df.head()

# %% [markdown]
# ## 1. Create a histogram of the house prices. Does the data look normally distributed (symmetrical, with no long tails)? Add a title and label the axes.

# %% [markdown]
# ## 2. On the above plot, change the font size to 20 and the color to blue.

# %% [markdown]
# ## 3. On the same plot, change the title font size to 25 whilst keeping everything else at size 20.

# %% [markdown]
# ## 4. Create a scatter plot of house price and age of the house. Add a title and label the axes.

# %% [markdown]
# ## 5. On the above plot, increase the size of the markers to 10 and set the opacity to 0.7.

# %% [markdown]
# ## 6. Change the colour of the markers to 'LightSkyBlue'

# %% [markdown]
# ## 7. Create a subplot and add your histogram and scatter plot to the subplot.

# %% [markdown]
# ## 8 Add a seperate title for the scatter plot and histogram

# %% [markdown]
# ## 9. Are there any variables with outliers? Which variable has the most outliers? (There is a plot that is particularly good at spotting outliers, you should be able to view all outliers in one figure)

# %% [markdown]
# ## 10. One column should have much more outliers than the others. What is causing this feature to have so many outliers? Answer this question with a visualisation, or relevant summary statistics.

# %% [markdown]
# ## 11. One of the first steps when building a model is to find out which variables are correlated with the target. Create a bar chart to show how each variable is correlated with house price. Anything over 0.25 or under -0.25 we would consider correlated.
# ## Tip: call df.corr() on the DataFrame to get a matrix of correlations for each variable. You only want the column relating to correlations between the target and all other features.

# %% [markdown]
# ## 12. Add the correlation of each feature to the top of each bar in the bar chart as a text label.
# ## Optional: (if you want a challenge) Make correlated variables a different colour to non-correlated variables.

# %% [markdown]
# ## 13. What is the mean correlation of all features? Add an annotation (text box) to the bar chart telling viewers what this value is.

# %% [markdown]
# ## 14. Are there any features highly correlated with eachother (excluding the target)? If the correlation is more than 0.8 or less than -0.8, we only need to use one of the features in a model, or we could transform one so that they are not correlated.

# %% [markdown]
# ## 15. Plot the highly correlated features (there should be only 1) with a trend line using pe.scatter().
# ## Write down your observations. Does anything look strange? If so, try to figure out why

# %% [markdown]
# ## 16. Bonus question: How could you transform one of the highly correlated features so that it is not correlated with the other one?
